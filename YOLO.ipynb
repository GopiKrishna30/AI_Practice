# %% [markdown]
# <a href="https://colab.research.google.com/github/GopiKrishna30/AI_Practice/blob/main/YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python

# %%
# Import Libraries
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# %%
# Uploading an Image
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b6945edf-b982-4c6f-8ac1-3d3985efe471" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b6945edf-b982-4c6f-8ac1-3d3985efe471">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Loading YOLO Model
model = YOLO('yolov8n.pt')

# %%
import numpy as np

# Get uploaded file name
image_path = list(uploaded.keys())[0]

# Read image
img = cv2.imread(image_path)

# Run Model
results = model(img)

# Show Result
annotated = results[0].plot()
cv2_imshow(annotated)
# Out:
# 0: 352x640 2 persons, 1 car, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
# <PIL.Image.Image image mode=RGB size=270x148>

# %%
# Saving the output image
cv2.imwrite("output.jpeg", annotated)
# Out:
# True

# %%
# Downloading the image
files.download("output.jpeg")
